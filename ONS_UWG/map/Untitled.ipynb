# %%
import jjson
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/h0/z64sm6g52rj9b3j8y6vvmdxm0000gn/T/ipykernel_16522/3060844463.py in <module>
# ----> 1 import jjson
#
# ModuleNotFoundError: No module named 'jjson'

# %%
import json

# %%
uk_regions = json.load(open("uk_regions.geojson",'r'))

# %%
uk_regions['features'][0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[-2.03, 55.77],
#      [-2.02, 55.77],
#      [-2.03, 55.77],
#      [-2.04, 55.76],
#      [-2.05, 55.76],
#      [-2.07, 55.76],
#      [-2.09, 55.76],
#      [-2.24, 55.65],
#      [-2.33, 55.63],
#      [-2.31, 55.62],
#      [-2.23, 55.52],
#      [-2.2, 55.48],
#      [-2.18, 55.47],
#      [-2.33, 55.41],
#      [-2.34, 55.39],
#      [-2.33, 55.39],
#      [-2.34, 55.39],
#      [-2.33, 55.39],
#      [-2.34, 55.37],
#      [-2.64, 55.26],
#      [-2.63, 55.25],
#      [-2.63, 55.23],
#      [-2.69, 55.19],
#      [-2.53, 55.08],
#      [-2.53, 55.09],
#      [-2.53, 55.08],
#      [-2.53, 55.09],
#      [-2.52, 55.09],
#      [-2.5, 55.09],
#      [-2.49, 55.09],
#      [-2.5, 55.09],
#      [-2.49, 55.09],
#      [-2.5, 55.07],
#      [-2.51, 55.04],
#      [-2.51, 55.03],
#      [-2.51, 55.04],
#      [-2.51, 55.03],
#      [-2.6, 54.97],
#      [-2.6, 54.96],
#      [-2.6, 54.97],
# ...
